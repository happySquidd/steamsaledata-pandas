# %%
import kagglehub
import pandas as pd
import os

# dpwnload the dataset
path = kagglehub.dataset_download("benjaminlundkvist/steam-sales-historical-dataset")

# create a correct path by using os
csv_path = os.path.join(path, 'steam_sales.csv')

df = pd.read_csv(csv_path)

# %%
# create a high discount data frame
high_discount_df = df[df["Discount%"] <= -70.0]
# sanitize fields
high_discount_df.dropna(subset=['Discount%'])

result_df = high_discount_df.sort_values(by=["Rating", "Discount%"], ascending=[False, True])
# show games with highest ratings and biggest discounts
result_df.loc[:, ["Game Name", "Rating", "#Reviews", "Discount%", "Price (€)", "Original Price (€)", "Release Date"]].head(20)
# Out:
#                                              Game Name  Rating  #Reviews  \
# 1089                                     Killing Floor     8.0   21223.0
# 1346                                          POSTAL 2     8.0   39573.0
# 1408                                 The Last Campfire     8.0    4527.0
# 91                      Spiritfarer®: Farewell Edition     8.0    42,589
# 511                     Spiritfarer®: Farewell Edition     8.0   42696.0
# 19         The Witcher 3: Wild Hunt - Complete Edition     8.0   787,763
# 27                            The Witcher 3: Wild Hunt     8.0   772,465
# 147                                               DOOM     8.0   145,528
# 281                                               GRIS     8.0    76,816
# 479                                         Black Mesa     8.0  123419.0
# 1049       Total War: MEDIEVAL II – Definitive Edition     8.0   15813.0
# 1064       Total War: MEDIEVAL II - Definitive Edition     8.0   25872.0
# 1314       Total War: MEDIEVAL II – Definitive Edition     8.0   15838.0
# 1345       Total War: MEDIEVAL II - Definitive Edition     8.0   25912.0
# 30                               Resident Evil Village     8.0    85,930
# 37                                     Devil May Cry 5     8.0   103,981
# 92                                     Resident Evil 2     8.0   122,245
# 136                                      Slime Rancher     8.0   125,005
# 144   The Walking Dead: The Telltale Definitive Series     8.0    24,325
# 146                        Sid Meier's Civilization® V     8.0   124,875
#
#       Discount%  Price (€)  Original Price (€)  Release Date
# 1089      -90.0       1.99               19.99  May 14, 2009
# 1346      -90.0       0.99                9.99   Nov 2, 2012
# 1408      -90.0       1.49               14.99   Oct 7, 2021
# 91        -85.0       4.34               28.99  18 Aug, 2020
# 511       -85.0       4.49               29.99  Aug 18, 2020
# 19        -80.0       9.99               49.99  30 Aug, 2016
# 27        -80.0       5.99               29.99  18 May, 2015
# 147       -80.0       3.99               19.99  12 May, 2016
# 281       -80.0       2.95               14.79  13 Dec, 2018
# 479       -80.0       3.99               19.99   Mar 6, 2020
# 1049      -80.0       4.99               24.99  Nov 27, 2007
# 1064      -80.0       4.99               24.99  Nov 27, 2007
# 1314      -80.0       4.99               24.99  Nov 27, 2007
# 1345      -80.0       4.99               24.99  Nov 27, 2007
# 30        -75.0       9.99               39.99   7 May, 2021
# 37        -75.0       7.49               29.99   7 Mar, 2019
# 92        -75.0       9.99               39.99  24 Jan, 2019
# 136       -75.0       4.74               18.99   1 Aug, 2017
# 144       -75.0      12.24               48.99  29 Oct, 2020
# 146       -75.0       7.49               29.99  23 Sep, 2010
